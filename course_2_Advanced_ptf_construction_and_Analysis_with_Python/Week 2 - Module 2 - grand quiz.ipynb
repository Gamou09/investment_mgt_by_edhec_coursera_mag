# %% [markdown]
# # Module 2 - Graded quizz

# %%
import numpy as np
import pandas as pd

import edhec_risk_kit_206 as erk

# %load_ext autoreload
# %autoreload 2
inds = ['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth',
       'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry',
       'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper',
       'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other']
#inds=['Beer', 'Hlth', 'Fin','Rtail','Whlsl']
ind_rets = erk.get_ind_returns(weighting="vw", n_inds=30)["1997":"2018"]
ind_mcap = erk.get_ind_market_caps(30, weights=True)["1997":"2018"]

# %%
ind_rets
# Out:
#            Food    Beer   Smoke   Games   Books   Hshld   Clths    Hlth  \
# 1997-01  0.0289  0.1136  0.0463  0.0359  0.0075  0.0643  0.0644  0.0955
# 1997-02  0.0279  0.0274  0.1247 -0.0026  0.0239  0.0287  0.0312  0.0094
# 1997-03 -0.0120 -0.0653 -0.1354 -0.0320  0.0071 -0.0606 -0.0566 -0.0740
# 1997-04  0.0337  0.1137  0.0324  0.0275 -0.0076  0.0845 -0.0410  0.0616
# 1997-05  0.0257  0.0643  0.0998  0.0560  0.0706  0.0815  0.0501  0.0691
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 2018-08 -0.0038 -0.0186 -0.0543  0.0289 -0.0447  0.0254  0.0526  0.0446
# 2018-09 -0.0032  0.0019  0.0537 -0.0009 -0.0221  0.0107  0.0130  0.0199
# 2018-10  0.0102 -0.0157  0.0790 -0.1596 -0.0666 -0.0051 -0.1014 -0.0884
# 2018-11  0.0272  0.0579 -0.0843 -0.0065  0.0325  0.0644 -0.0099  0.0632
# 2018-12 -0.0973 -0.0969 -0.1580 -0.0824 -0.1535 -0.0557 -0.0728 -0.0840
#
#           Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# ...

# %%
ind_mcap
# Out:
#              Food      Beer     Smoke     Games     Books     Hshld     Clths  \
# 1997-01  0.027453  0.027252  0.014657  0.014549  0.011205  0.025672  0.006593
# 1997-02  0.026682  0.028846  0.014576  0.014316  0.010713  0.025952  0.006670
# 1997-03  0.027449  0.029690  0.016412  0.014255  0.010974  0.026720  0.006892
# 1997-04  0.028461  0.029152  0.014778  0.014524  0.011629  0.026376  0.006836
# 1997-05  0.028110  0.031130  0.014630  0.014290  0.011052  0.027371  0.006287
# ...           ...       ...       ...       ...       ...       ...       ...
# 2018-08  0.021873  0.008309  0.008222  0.011997  0.001168  0.014569  0.009720
# 2018-09  0.021005  0.007873  0.007515  0.011923  0.001076  0.014427  0.009874
# 2018-10  0.020661  0.007862  0.007831  0.011851  0.001052  0.014606  0.010000
# 2018-11  0.022649  0.008403  0.009178  0.010810  0.001066  0.015702  0.009761
# 2018-12  0.022832  0.008763  0.008291  0.010589  0.001083  0.016477  0.009510
#
# ...

# %%
ewr = erk.backtest_ws(ind_rets, estimation_window=36, weighting=erk.weight_ew)
cwr = erk.backtest_ws(ind_rets, estimation_window=36, weighting=erk.weight_cw, cap_weights=ind_mcap)
btr = pd.DataFrame({"EW": ewr, "CW": cwr})
(1+btr).cumprod().plot(figsize=(12,6), title="Industry Portfolios - CW vs EW")
erk.summary_stats(btr.dropna())
# Out:
#     Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# EW           0.077614        0.158685 -0.538531  5.317042
# CW           0.065196        0.151478 -0.556621  4.249894
#
#     Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  Max Drawdown
# EW                 0.072485            0.106220      0.291838      -0.53298
# CW                 0.071076            0.098531      0.225949      -0.51899

# %%
# btr["1999":"2001"] #to confirm that the backtesting started 1997 + 36months (3 years)
# ind_rets

# %%
# weight_ew(r, cap_weights=None, max_cw_mult=None, microcap_threshold=None, **kwargs)
ewr_tethered = erk.backtest_ws(ind_rets, estimation_window=36, weighting=erk.weight_ew, cap_weights=ind_mcap, max_cw_mult=2, microcap_threshold=0.01)
btr = pd.DataFrame({"EW": ewr, "CW": cwr, "Tethered EW": ewr_tethered})
(1+btr).cumprod().plot(figsize=(12,6), title="Industry Portfolios")
erk.summary_stats(btr.dropna())
# Out:
#              Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# EW                    0.077614        0.158685 -0.538531  5.317042
# CW                    0.065196        0.151478 -0.556621  4.249894
# Tethered EW           0.076838        0.140774 -0.649872  4.664374
#
#              Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# EW                          0.072485            0.106220      0.291838
# CW                          0.071076            0.098531      0.225949
# Tethered EW                 0.065482            0.093766      0.323653
#
#              Max Drawdown
# EW              -0.532980
# CW              -0.518990
# Tethered EW     -0.487413

# %%
erk.tracking_error(ewr, cwr)
# Out:
# 0.18752094143646486

# %%
erk.tracking_error(ewr_tethered, cwr)
# Out:
# 0.11671015519949166

# %%
# weight_gmv(r, cov_estimator=sample_cov, **kwargs):
mv_s_r = erk.backtest_ws(ind_rets, estimation_window=36, weighting=erk.weight_gmv, cov_estimator=erk.sample_cov)
btr = pd.DataFrame({"EW": ewr, "CW": cwr, "Tethered EW": ewr_tethered, "GMV-Sample": mv_s_r})
(1+btr).cumprod().plot(figsize=(12,6), title="Industry Portfolios")
erk.summary_stats(btr.dropna())
# Out:
#              Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# EW                    0.077614        0.158685 -0.538531  5.317042
# CW                    0.065196        0.151478 -0.556621  4.249894
# Tethered EW           0.076838        0.140774 -0.649872  4.664374
# GMV-Sample            0.066306        0.117410 -0.741087  4.469208
#
#              Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# EW                          0.072485            0.106220      0.291838
# CW                          0.071076            0.098531      0.225949
# Tethered EW                 0.065482            0.093766      0.323653
# GMV-Sample                  0.055456            0.080583      0.300815
#
#              Max Drawdown
# EW              -0.532980
# CW              -0.518990
# Tethered EW     -0.487413
# GMV-Sample      -0.421289

# %%
# shrinkage_cov(r, delta=0.5, **kwargs)
mv_sh_r = erk.backtest_ws(ind_rets, estimation_window=36, weighting=erk.weight_gmv, cov_estimator=erk.shrinkage_cov, delta=0.25)
btr = pd.DataFrame({"EW": ewr, "CW": cwr, "Tethered EW": ewr_tethered, "GMV-Sample": mv_s_r, 'GMV-Shrink 0.25': mv_sh_r})
(1+btr).cumprod().plot(figsize=(12,6), title="Industry Portfolios")
erk.summary_stats(btr.dropna())
# Out:
#                  Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# EW                        0.077614        0.158685 -0.538531  5.317042
# CW                        0.065196        0.151478 -0.556621  4.249894
# Tethered EW               0.076838        0.140774 -0.649872  4.664374
# GMV-Sample                0.066306        0.117410 -0.741087  4.469208
# GMV-Shrink 0.25           0.068466        0.114572 -0.731288  4.264931
#
#                  Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# EW                              0.072485            0.106220      0.291838
# CW                              0.071076            0.098531      0.225949
# Tethered EW                     0.065482            0.093766      0.323653
# GMV-Sample                      0.055456            0.080583      0.300815
# GMV-Shrink 0.25                 0.053884            0.077715      0.326627
#
#                  Max Drawdown
# EW                  -0.532980
# ...

# %%
btr = pd.DataFrame({"EW": ewr, "CW": cwr, "Tethered EW": ewr_tethered, "GMV-Sample": mv_s_r, 'GMV-Shrink 0.25': mv_sh_r})
(1+btr).cumprod().plot(figsize=(12,6), title="Industry Portfolios")
erk.summary_stats(btr.dropna())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/y0/y9b7zlz53n53dq8hm2lh15_w0000gn/T/ipykernel_8525/3174887938.py in <module>
# ----> 1 btr = pd.DataFrame({"EW": ewr, "CW": cwr, "Tethered EW": ewr_tethered, "GMV-Sample": mv_s_r, 'GMV-Shrink 0.25': mv_sh_r})
#       2 (1+btr).cumprod().plot(figsize=(12,6), title="Industry Portfolios")
#       3 erk.summary_stats(btr.dropna())
#
# NameError: name 'pd' is not defined

# %%
ind_mcap
# Out:
#              Food      Beer     Smoke     Games     Books     Hshld     Clths  \
# 1997-01  0.027453  0.027252  0.014657  0.014549  0.011205  0.025672  0.006593
# 1997-02  0.026682  0.028846  0.014576  0.014316  0.010713  0.025952  0.006670
# 1997-03  0.027449  0.029690  0.016412  0.014255  0.010974  0.026720  0.006892
# 1997-04  0.028461  0.029152  0.014778  0.014524  0.011629  0.026376  0.006836
# 1997-05  0.028110  0.031130  0.014630  0.014290  0.011052  0.027371  0.006287
# ...           ...       ...       ...       ...       ...       ...       ...
# 2018-08  0.021873  0.008309  0.008222  0.011997  0.001168  0.014569  0.009720
# 2018-09  0.021005  0.007873  0.007515  0.011923  0.001076  0.014427  0.009874
# 2018-10  0.020661  0.007862  0.007831  0.011851  0.001052  0.014606  0.010000
# 2018-11  0.022649  0.008403  0.009178  0.010810  0.001066  0.015702  0.009761
# 2018-12  0.022832  0.008763  0.008291  0.010589  0.001083  0.016477  0.009510
#
# ...
